# %% [markdown]
# # Real Estate AI Major Project\nThis notebook trains and evaluates the included synthetic dataset.

# %%
import pandas as pd\ndf=pd.read_csv('../data/property_transactions.csv')\ndf.head()

# %%
df.groupby('locality').agg(median_price=('price_inr','median'),median_rent=('monthly_rent_inr','median')).sort_values('median_price',ascending=False)

# %%
# Train the project models from the command line as well:\n# !python ../src/train_models.py
